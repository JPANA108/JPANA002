# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter  # 次數統計
#from wordcloud import WordCloud, STOPWORDS
#import WordCloud

dictfile = r"C:\Users\user\Desktop\py\wordcloud\字典1.txt"  # 字典檔
stopfile = r"C:\Users\user\Desktop\py\wordcloud\stop1.txt"  # stopwords
fontpath = r"c:/test-wordcloud/msjh.ttc"  # 字型檔

mdfile = r"C:\Users\user\Desktop\HELP\使用經驗-研究方向或主題.csv"  # 文檔
pngfile = r"C:\Users\user\Desktop\py\wordcloud\S__50642974.jpg"  # 剛才下載存的底圖
userdict_file_path = r"C:\Users\user\Desktop\py\wordcloud\userdict.txt"

font = r'msjh.ttc'
ggmask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)
jieba.load_userdict(userdict_file_path)

text = open(mdfile, "r", encoding='utf-8-sig').read()

tags = jieba.analyse.extract_tags(text, topK=25)

seg_list = jieba.lcut(text, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq)  # 計算出現的次數

'''
wordcloud = WordCloud(background_color="white",
                      mask=ggmask,
                      font_path=font,
                      collocations=False,
                      width=4800,
                      height=4800,
                      colormap='Set2',
                      margin=2).generate_from_frequencies(freq)
'''
wordcloud = WordCloud(relative_scaling=0,
                      collocations=False,
                      background_color="white",
                      width=2400,
                      height=2400,
                      contour_color = 'Tableau Palette',
                      margin=2,
                      font_path=font
                      ).generate_from_frequencies(freq)


plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

fig_path = r'C:\Users\user\Desktop\py\wordcloud\out.png'
wordcloud.to_file(fig_path)
# Out:
# Building prefix dict from C:\Users\user\Desktop\py\wordcloud\字典1.txt ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.ue00849a5f05026ae0c7f2c06724f8ca9.cache
# Loading model cost 0.365 seconds.
# Prefix dict has been built successfully.
# {'公共': 2, '人力': 1, '資源': 1, '管理': 1, '文官': 1, '制度': 1, '組織行為': 1, '選舉': 2, '政治': 3, '傳播': 1, '國際關係': 2, '國內政治': 1, '兩岸關係': 1, '科技': 1, '性別': 1, '民主化': 1, '政治態度': 1, '文化': 1, '人口學': 1, '民主': 1, '態度': 1, '選民': 1, '投票': 1, '行為': 1, '原住民': 1}

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter  # 次數統計
#from wordcloud import WordCloud, STOPWORDS
#import WordCloud

dictfile = r"C:\Users\user\Desktop\py\wordcloud\字典1.txt"  # 字典檔
stopfile = r"C:\Users\user\Desktop\py\wordcloud\stop1.txt"  # stopwords
fontpath = r"c:/test-wordcloud/msjh.ttc"  # 字型檔

mdfile = r"C:\Users\user\Desktop\HELP\count15-1.csv"  # 文檔
pngfile = r"C:\Users\user\Desktop\py\wordcloud\S__50642974.jpg"  # 剛才下載存的底圖
userdict_file_path = r"C:\Users\user\Desktop\py\wordcloud\userdict.txt"

font = r'msjh.ttc'
ggmask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)
jieba.load_userdict(userdict_file_path)

text = open(mdfile, "r", encoding='utf-8-sig').read()

tags = jieba.analyse.extract_tags(text, topK=10)

seg_list = jieba.lcut(text, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq)  # 計算出現的次數


wordcloud = WordCloud(background_color="white",
                      mask=mask,
                      font_path=font,
                      collocations=False,
                      width=2400,
                      height=2400,
                      colormap='Set2',
                      margin=2).generate_from_frequencies(freq)
'''
wordcloud = WordCloud(relative_scaling=0,
                      collocations=False,
                      width=2400,
                      height=2400,
                      contour_color = 'steelblue',
                      margin=2,
                      font_path=font
                      ).generate_from_frequencies(freq)
'''

plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

fig_path = r'C:\Users\user\Desktop\py\wordcloud\out.png'
wordcloud.to_file(fig_path)
# Out:
# Building prefix dict from C:\Users\user\Desktop\py\wordcloud\字典1.txt ...
# Loading model from cache C:\Temp\Temp\jieba.ue00849a5f05026ae0c7f2c06724f8ca9.cache
# Loading model cost 0.367 seconds.
# Prefix dict has been built successfully.
# {'經濟': 1, '學生': 1, '兒童': 1, '學習': 1, '影響': 1, '心理': 2, '加速': 2, '測量': 2, '問卷': 2, '時間': 2}

# %%
text
# Out:
# '家庭研究\n政策與兩性議題\n學生學習成效、經濟與文化不利學生學習成效\n中年失業，勞動市場早退\n家庭、教育、勞動研究\n休閒旅遊\n健康及長照研究\n行銷管理\n公共人力資源管理\n行銷研究\n特殊教育\n家庭研究\n家庭社會學與女性生育\n老人\n勞動市場、婦女就業、中高齡就業\n傳播科技\n勞動\n學習成就研究、家庭研究\n家庭研究\n社會心理、家人關係、溝通互動等\n教育\n教育行政和政策\n休閒遊憩\n文官制度、公共組織行為\n國家安全態度\n幼兒教育\n臨床心理、適應、發展、家庭關係\n數位落差\n性別研究\nXXX\n企業經營管理\n勞動經濟\nEnvironmental Economics\n家庭研究\n企業管理議題\n老年與家庭\n家庭\n家庭研究\n正向老化、工作壓力\n老年人口研究\n教育行政與領導\n觀光產業與區域經濟發展\nfamily\n親職，幼兒園\n行銷管理\n老年人口\n兩岸家庭研究\n年輕人學習經驗生命史研究\n員工行為\n環境與能源經濟、家庭研究\n勞動行為、家庭人口研究\n社會階層\nOBHR \n兒童青少年健康、家庭研究\n建立唯手機族與有線電話雙樣本的電話調查標準作業模式\n社會心理與人際互動\n中國大陸\n兒童及青少年運動與健康\n選舉研究\n性別與老化\n青少年、青年\n兒童發展、家庭研究\n家庭研究\nsocial policy\n心理領域\n教育專門領域\n校務研究、校務治理、 國際化\n環境\n"國際教育\n雙語教學"\n政治傳播\n性別與教育、另類與實驗教育\n旅遊目的地\n成就動機、心理健康\n親職研究、家庭研究\n家庭研究\n旅運行為分析\n幼兒發展\n勞動決策、老年人口\n老人\n家庭研究、人口學\n國際關係\n健康社會學\n特殊教育\n公共衛生營養研究\n老年人口研究\n街道命名研究與區域研究\n研究方法、主觀福祉\n偏遠地區學校\n政治經濟\n領導研究\n國內政治及兩岸關係\nPISA科學領域\n老年人口研究\n心理計量 靈性研究\n組織行為、人力資源管理\n糖尿病病人行為\n政治經濟學研究\n經濟成長、貨幣政策\n調查研究方法\n科技與性別\n青少年憂鬱情緒\n民主化、政治態度、政治文化\n貧窮\n心理計量\n勞動法\n青少年\n'
