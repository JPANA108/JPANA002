# %%
import pandas as pd

path = r'C:\Users\user\Desktop\HELP\important\clean1209-5-累加_直接砍重複值.xlsx'

data = pd.read_excel(path)

data
# Out:
#     計畫主持人    號                   學校名稱_x  \
# 0     丁一顧  SS2         臺北市立大學教育行政與評鑑研究所
# 1     王珮玲    1             臺北市立大學幼兒教育學系
# 2     何希慧  SS2         臺北市立大學教育行政與評鑑研究所
# 3     吳清山  SS2         臺北市立大學教育行政與評鑑研究所
# 4     金瑞芝  SS2             臺北市立大學幼兒教育學系
# ..    ...  ...                      ...
# 841   劉蕙苓  SS2       國立臺北藝術大學藝術行政與管理研究所
# 842   鄭青展    1  台北海洋學校財團法人台北海洋科技大學餐飲管理系
# 843   鄭英傑    1             國立體育大學師資培育中心
# 844   謝宜君    1              嶺東科技大學國際企業系
# 845   鍾紹熙  SS1      美和學校財團法人美和科技大學企業管理系
#
#                                                計畫名稱   核定金額_x    執行期限(起)  \
# 0                          國小校長優勢本位領導教練：理論、工具與實踐之研究  1591000  109/08/01
# 1                             高低努力控制幼兒在挫折情境下之情緒調節策略   677000  109/08/01
# 2                擺盪在教學與研究間: 談我國高等教育推動教學與研究連結的可行性與挑戰  1695000  110/08/01
# 3                     中小學校長素養導向領導之研究：指標建構、量表發展與實踐運用  1964000  108/08/01
# 4                                    父母罹癌對兒童生活品質之影響  1442000  106/08/01
# ...

# %%
import plotly.express as px

df = pd.read_excel(path)
fig = px.scatter(df, x="學門名稱2", y="核定金額_y", title='學門分類與計畫核定金額')
fig.update_xaxes(type='category')

fig.update_yaxes(autorange=True)
fig.update_yaxes(automargin=True)
fig.show()
# Out:
# <div>                            <div id="1e384bdd-48c9-4517-8549-5b9dfe72d886" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e384bdd-48c9-4517-8549-5b9dfe72d886")) {                    Plotly.newPlot(                        "1e384bdd-48c9-4517-8549-5b9dfe72d886",                        [{"hovertemplate":"\u5b78\u9580\u540d\u7a312=%{x}<br>\u6838\u5b9a\u91d1\u984d_y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["\u6559\u80b2\u884c\u653f","\u5e7c\u5152\u6559\u80b2","\u6559\u80b2\u884c\u653f","\u6559\u80b2\u884c\u653f","\u5e7c\u5152\u6559\u80b2","\u6559\u80b2\u884c\u653f","\u81e8\u5e8a\u8207\u8aee\u5546\u5fc3\u7406\u5b78","\u4ea4\u901a\u904b\u
# ...

# %%
import plotly.express as px

df = pd.read_excel(path)
fig = px.scatter(df, x="公私立", y="核定金額_x", title='學門分類與計畫核定金額',size='研究年期_y')
fig.update_xaxes(type='category')

fig.update_yaxes(autorange=True)
fig.update_yaxes(automargin=True)
fig.show()
# Out:
# <div>                            <div id="77e271fb-3b54-4cc4-8468-58ebed343b1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77e271fb-3b54-4cc4-8468-58ebed343b1d")) {                    Plotly.newPlot(                        "77e271fb-3b54-4cc4-8468-58ebed343b1d",                        [{"hovertemplate":"\u516c\u79c1\u7acb=%{x}<br>\u6838\u5b9a\u91d1\u984d_x=%{y}<br>\u7814\u7a76\u5e74\u671f_y=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[4,5,4,4,2,2,3,1,1,2,3,1,2,1,2,9,3,7,1,5,2,1,2,2,4,2,1,3,1,1,1,1,10,3,2,6,2,3,3,3,1,2,4,2,8,3,2,1,4,2,8,11,8,3,2,2,3,7,6,1,3,9,1,3,1,4,5,1,5,1,1,1,3,2,1,1,1,1,1,5,1,2,4,2,1,2,1,2,1,9,2,1,11,4,6,3,4,1,7,5,5,3,13,3,2,3,9,4,2,2,1,6,2,2,3,5,2,3,16,3,2,3,2,6,2,1,7,7,2,4,2,1,4,5,2,3
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_excel(path)
fig = px.histogram(df, x='年份_x', y="核定金額_x",color="地區", pattern_shape="公私立")


fig.show()
# Out:
# <div>                            <div id="7658f379-2afc-42fe-84eb-8057e7b74154" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7658f379-2afc-42fe-84eb-8057e7b74154")) {                    Plotly.newPlot(                        "7658f379-2afc-42fe-84eb-8057e7b74154",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"\u5730\u5340=\u5317\u90e8<br>\u516c\u79c1\u7acb=\u516c\u7acb<br>\u5e74\u4efd_x=%{x}<br>sum of \u6838\u5b9a\u91d1\u984d_x=%{y}<extra></extra>","legendgroup":"\u5317\u90e8, \u516c\u7acb","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u5317\u90e8, \u516c\u7acb","offsetgroup":"\u5317\u90e8, \u516c\u7acb","orientation":"v","showlegend":true,"x":[109,109,110,108,106,109,110,108,110,
# ...

# %%
import plotly.express as px

df = pd.read_excel(path)
fig = px.scatter(df, x="研究年期_x", y="核定金額_x", title='研究年期與核定金額', color='研究年期_y', size='研究年期_y')
fig.update_xaxes(type='category')


fig.show()
# Out:
# <div>                            <div id="578046a2-96ca-4459-8c20-bd2e351106bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("578046a2-96ca-4459-8c20-bd2e351106bb")) {                    Plotly.newPlot(                        "578046a2-96ca-4459-8c20-bd2e351106bb",                        [{"hovertemplate":"\u7814\u7a76\u5e74\u671f_x=%{x}<br>\u6838\u5b9a\u91d1\u984d_x=%{y}<br>\u7814\u7a76\u5e74\u671f_y=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[4,5,4,4,2,2,3,1,1,2,3,1,2,1,2,9,3,7,1,5,2,1,2,2,4,2,1,3,1,1,1,1,10,3,2,6,2,3,3,3,1,2,4,2,8,3,2,1,4,2,8,11,8,3,2,2,3,7,6,1,3,9,1,3,1,4,5,1,5,1,1,1,3,2,1,1,1,1,1,5,1,2,4,2,1,2,1,2,1,9,2,1,11,4,6,3,4,1,7,5,5,3,13,3,2,3,9,4,2,2,1,6,2,2,3,5,2,3,16,3,2,3,2,6,2,1,7,7,2,4,2,1,4,5,2,3,8,11,3,
# ...

# %%
import plotly.express as px

df = pd.read_excel(path)
fig = px.line(df, x="研究年期_y", y="核定金額_y", size='計畫主持人')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [25], line 4
#       1 import plotly.express as px
#       3 df = pd.read_excel(path)
# ----> 4 fig = px.line(df, x="研究年期_y", y="核定金額_y", size='計畫主持人')
#       5 fig.show()
#
# TypeError: line() got an unexpected keyword argument 'size'

# %%
import plotly.express as px

df = px.data.stocks(indexed=True)-1
fig = px.bar(df, x=df.index, y="GOOG")
fig.show()
